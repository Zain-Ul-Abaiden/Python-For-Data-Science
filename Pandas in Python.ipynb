# %%
# Pandas stands for Panel Data and is the core library for data manipulation and data analysis.
# It consists of single and multi demensional data structure for manipulation.

# %%
# single demensional --- series object
# multi-demensional --- data-frame

# %%
# series object is one-demensional labled array

# %%
import pandas as pd

# %%
s1 = pd.Series([11,22,34,56,76])

# %%
s1
# Out:
# 0    11
# 1    22
# 2    34
# 3    56
# 4    76
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
# changing index

# %%
s2 = pd.Series([11,22,34,56,76],index=['a','b','c','d','e'])
s2
# Out:
# a    11
# b    22
# c    34
# d    56
# e    76
# dtype: int64

# %%
# series object from dictionary

# %%
s3 = pd.Series({'a':11,'b':22,'c':34,'d':56,'e':76})
s3
# Out:
# a    11
# b    22
# c    34
# d    56
# e    76
# dtype: int64

# %%
# changing index series

# %%
s4 = pd.Series({'a':11,'b':22,'c':34,'d':56,'e':76},index=['c','a','b','f','d'])
s4
# Out:
# c    34.0
# a    11.0
# b    22.0
# f     NaN
# d    56.0
# dtype: float64

# %%
# extracting individual element

# %%
# extracting a single element
s5 = pd.Series([1,2,3,4,5])
s5[3]
# Out:
# 4

# %%
# extracting a sequence of element
s5[:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# extracting element from back
s5[-3:]
# Out:
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# basic mathematic operation on series

# %%
# adding a scaler value we can subtract, multiply and devison as well
s5+5
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
# adding two series object

# %%
s1+s5
# Out:
# 0    12
# 1    24
# 2    37
# 3    60
# 4    81
# dtype: int64

# %%
# Pandas DataFrame

# %%
# DataFrame is a two demensional labelled data structure
# A DataFrame comprises rows and columns

# %%
# creating a DatFrame with dictionary

d1 = pd.DataFrame({"Name":['zain','waseem','akram'],"Marks":[78,98,76]})
d1
# Out:
#      Name  Marks
# 0    zain     78
# 1  waseem     98
# 2   akram     76

# %%
# Built in function in DataFrame

# %%
customer = pd.read_csv('customers-100.csv')

# %%
# first 5 index data

customer.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# last 5 index data

customer.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
# find rows and columns

customer.shape
# Out:
# (100, 12)

# %%
# describe the data

customer.describe
# Out:
# <bound method NDFrame.describe of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
# extract rows and columns

customer.iloc[0:3,5:7]
# Out:
#                 City              Country
# 0       East Leonard                Chile
# 1  East Jimmychester             Djibouti
# 2      Isabelborough  Antigua and Barbuda

# %%
customer.loc[0:3,"City":"Country"]
# Out:
#                 City              Country
# 0       East Leonard                Chile
# 1  East Jimmychester             Djibouti
# 2      Isabelborough  Antigua and Barbuda
# 3         Bensonview   Dominican Republic

# %%
customer.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# drop columns

customer.drop('Website',axis=1)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
# drop rows

customer.drop([2,4,5],axis=0)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 6       7  EA4d384DfDbBf77     Darren      Peck
# 7       8  0e04AFde9f225dE      Brett    Mullen
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City             Country  \
# 0                   Rasmussen Group       East Leonard               Chile
# 1                       Vega-Gentry  East Jimmychester            Djibouti
# 3   Dominguez, Mcmillan and Donovan         Bensonview  Dominican Republic
# 6      Lester, Woodard and Mitchell           Lake Ana    Pitcairn Islands
# ...

# %%
# mean , median, minimum, maximum
# .mean(), .median(), .min(), .max()

# %%
# more function

# half of particular columns

# def half(s):
#    return s/2

#customer[['country','City']].apply(half)

# %%
# value count
customer['Country'].value_counts()
# Out:
# Country
# Solomon Islands                     4
# Saint Vincent and the Grenadines    2
# Bulgaria                            2
# Oman                                2
# Netherlands                         2
#                                    ..
# United States of America            1
# Liechtenstein                       1
# Denmark                             1
# Tanzania                            1
# Honduras                            1
# Name: count, Length: 85, dtype: int64

# %%
# sort values
customer.sort_values(by='
